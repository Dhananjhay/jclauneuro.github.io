# %% [markdown]
# _Adapted from notebook used by [nbclab.github.io](https://nbclab.github.io)._
#
# # Retrieve new publications from PubMed
#
# This notebook is used to search for and retrieve latest publications by Dr. Khan using BioPython's PubMed search tool. A publication-specific MarkDown file is generated for each unique paper, with many elements automatically set up. As noted in the original notebook, you generally should check that the link to the markdown file exists. Unfortunately, preprints cannot be found via this method (though they can be added manually). This notebook cannot find new preprints. The process is automated and runs monthly using Github actions.
#
# ## Steps (via Github or manual)
#
# 1. Run this notebook.
# 2. If any new papers were grabbed, check the following:
#     1. The paper has either of the lab PIs as an author. Ensure that it isn't by *another* AR Khan.
#     2. The paper is not a duplicate of a preprint or another version of the paper. If so, merge the two versions.
# 3. Save the changes to the notebook.
# 4. Push changes to the notebook and affected files to GitHub.
# 5. Open a pull request to khanlab/khanlab.github.io

# %%
# Libraries
import os 

from Bio import Entrez, Medline
from datetime import datetime
from dateutil import parser
import pandas as pd

# %% [markdown]
# ### Check existing publications

# %%
# First count number of articles from previous grab
pub_data = "_data/publications/publications.csv"

# Update count of publications from existing file
old_count = 0 
if os.path.isfile(pub_data):
    df_old = pd.read_csv(pub_data)
    old_count = len(df_old)

# %% [markdown]
# ### Perform new query

# %%
# Only grab papers from after the lab PI came to UWO
search_criteria = ['''"Khan AR"[AUTH] AND ("2015/01/01"[PDAT] : "3000/12/31"[PDAT]) AND
                    ("Western University"[AFFL] OR "University of Western Ontario"[AFFL] OR
                     "Brain and Mind Institute"[AFFL] OR "Robarts Research Institute"[AFFL])''']

# Email required to search
Entrez.email = ''

# %%
rows = []

# Publications to skip (possibly due to another user with same initial)
skip_pmids = [32971934, 29641820, 29634829]
skip_pmids = [str(pmid) for pmid in skip_pmids]

for TERM in search_criteria:
    search = Entrez.esearch(db="pubmed", retmax="2", term=TERM)
    result = Entrez.read(search)
    print(f"Total number of publications containing {TERM}: {result['Count']}")
    
    search_all = Entrez.esearch(db="pubmed", term=TERM, retmax=result["Count"])
    result_all = Entrez.read(search_all)
    ids_all = result_all['IdList']
    pubs_all = Entrez.efetch(db="pubmed", id=ids_all, rettype='medline', retmode='text')
    records = Medline.parse(pubs_all)
    
    acceptable_formats = ["journal article", "comparative study", "editorial"]
    
    for record in records:
        if any([type_.lower() in acceptable_formats for type_ in record.get('PT')]):
            pmid = record.get("PMID")
            pmcid = record.get("PMC", "")
            
            doi = [aid for aid in record.get("AID", []) if aid.endswith(" [doi]")]
            if doi:
                doi = doi[0].replace(" [doi]", "")
            else:
                doi = ""
            
            title = record.get("TI").rstrip(".")
            authors = record.get("AU")
            
            pub_date = parser.parse(record.get("DP"))
            journal = record.get('TA')
            volume = record.get('VI', '')
            issue = record.get('IP', '')
            pages = record.get('PG', '')
            
            row = [pmid, pmcid, doi, title, authors, pub_date.year, pub_date.month,
                   pub_date.day, journal, volume, issue, pages]
            rows += [row]
            
df = pd.DataFrame(columns=['pmid', 'pmcid', 'doi', 'title', 'authors',
                           'year', 'month', 'day',
                           'journal', 'volume', 'issue', 'pages'],
                  data=rows)
df = df[~df["pmid"].isin(skip_pmids)]
df['pmid'] = df['pmid'].astype(int)

new_pubs = df[~df['pmid'].isin(df_old['pmid'])]

# Append to old pubs to solve date issue
df = df_old.append(new_pubs)
df = df.sort_values(by=['year', 'month', 'day'], ascending=False)
df = df.fillna('')

# Save all relevant info from articles to a csv.
print("Saving identified publications to csv...")
df.to_csv('_data/publications/publications.csv', index=False)
# Out:
# Total number of publications containing "Khan AR"[AUTH] AND ("2015/01/01"[PDAT] : "3000/12/31"[PDAT]) AND
#                     ("Western University"[AFFL] OR "University of Western Ontario"[AFFL] OR
#                      "Brain and Mind Institute"[AFFL] OR "Robarts Research Institute"[AFFL]): 95
# Saving identified publications to csv...
# /tmp/ipykernel_2612/990535001.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_old.append(new_pubs)

# %%
# Add papers we already have pages for.
if len(skip_pmids) > 0:
    for pmid in skip_pmids:
        df = df[df['pmid'] != pmid]
        
print(f"{len(df)} total articles found.")
print(f"{len(df) - old_count} new articles found.")

print("\nNew publications found:")
for _, pub in new_pubs.iterrows():
    print(f"Title: {pub['title']} ({pub['journal']})")
    print(f"Authors: {pub['authors']}")
    print(f"Journal (Date): {pub['journal']} ({pub['month']}/{pub['day']}/{pub['year']})\n")
# Out:
# 91 total articles found.
# 90 new articles found.
#
# New publications found:
# Title: Microstructural variation of hippocampal substructures across childhood and adolescence quantified with high-gradient diffusion MRI (Commun Biol)
# Authors: ['Karat BG', 'Genc S', 'Raven EP', 'Palombo M', 'Khan AR', 'Jones DK']
# Journal (Date): Commun Biol (2/12/2026)
#
# Title: Revisiting the interpretation of axon diameter mapping using higher-order signal representations (Imaging Neurosci (Camb))
# Authors: ['Karat BG', 'Wren-Jarvis J', 'Raven EP', 'Khan AR', 'Jones DK', 'Palombo M', 'Veraart J']
# Journal (Date): Imaging Neurosci (Camb) (3/1/2026)
#
# Title: Hippocampal grey matter changes across scales in Alzheimer's Disease (bioRxiv)
# Authors: ['Karat BG', 'Farahani MV', 'Davidson M', 'Thurairajah A', 'Taha A', 'Schmitz TW', 'Khan AR']
# Journal (Date): bioRxiv (10/15/2025)
#
# Title: HippoMaps: multiscale cartography of human hippocampal organization (Nat Methods)
# Authors: ['DeKraker J', 'Cabalo DG', 'Royer J', 'Ngo A', 'Khan AR', 'Karat BG', 'Benkarim O', 'Rodriguez-Cruces R', 'Frauscher B', 'Pana R', 'Hansen JY', 'Misic B', 'Valk SL', 'Lau JC', 'Kirschner M', 'Bernasconi A', 'Bernasconi N', 'Muenzing SEA', 'Axer M', 'Amunts K', 'Evans AC', 'Bernhardt BC']
# Journal (Date): Nat Methods (10/1/2025)
#
# Title: Imaging of the superficial white matter in health and disease (Imaging Neurosci (Camb))
# Authors: ['Van Dyken PC', 'Khan AR', 'Palaniyappan L']
# Journal (Date): Imaging Neurosci (Camb) (3/1/2024)
#
# Title: Hippocampal microscopic fractional anisotropy is reduced in temporal lobe epilepsy (Imaging Neurosci (Camb))
# Authors: ['Arezza NJJ', 'Abbas HH', 'Chadwick C', 'Johnsrude IS', 'Burneo JG', 'Suller Marti A', 'Khan AR', 'Baron CA']
# Journal (Date): Imaging Neurosci (Camb) (3/1/2024)
#
# Title: Neurite Density and Kurtosis in the Gray Matter of People With Early Schizophrenia (Biol Psychiatry Cogn Neurosci Neuroimaging)
# Authors: ['Van Dyken PC', 'Khan AR', 'Palaniyappan L']
# Journal (Date): Biol Psychiatry Cogn Neurosci Neuroimaging (1/1/2026)
#
# Title: Early life stress impairs hippocampal subfield myelination (Commun Biol)
# Authors: ['Nichols ES', 'Karat BG', 'Grace M', 'Bezanson S', 'Khan AR', 'Duerden EG']
# Journal (Date): Commun Biol (5/22/2025)
#
# Title: Midbrain and pallidal iron changes identify patients with REM sleep behaviour disorder and Parkinson's disease (NPJ Parkinsons Dis)
# Authors: ['Alushaj E', 'Kuurstra A', 'Menon RS', 'Ganjavi H', 'Morava A', 'Sharma M', 'Kashgari A', 'Barr J', 'Reisman W', 'Khan AR', 'MacDonald PA']
# Journal (Date): NPJ Parkinsons Dis (4/23/2025)
#
# Title: Stable White Matter Structure in the First Three Years After Psychosis Onset (Biol Psychiatry Glob Open Sci)
# Authors: ['Van Dyken PC', 'Yang K', 'Faria AV', 'Sawa A', 'MacKinley M', 'Khan AR', 'Palaniyappan L']
# Journal (Date): Biol Psychiatry Glob Open Sci (5/1/2025)
#
# Title: Convergence of Cannabis and Psychosis on the Dopamine System (JAMA Psychiatry)
# Authors: ['Ahrens J', 'Ford SD', 'Schaefer B', 'Reese D', 'Khan AR', 'Tibbo P', 'Rabin R', 'Cassidy CM', 'Palaniyappan L']
# Journal (Date): JAMA Psychiatry (6/1/2025)
#
# Title: Gauge equivariant convolutional neural networks for diffusion MRI (Sci Rep)
# Authors: ['Hussain U', 'Khan AR']
# Journal (Date): Sci Rep (3/20/2025)
#
# Title: Multimodal gradients of basal forebrain connectivity across the neocortex (Nat Commun)
# Authors: ['Chakraborty S', 'Haast RAM', 'Onuska KM', 'Kanel P', 'Prado MAM', 'Prado VF', 'Khan AR', 'Schmitz TW']
# Journal (Date): Nat Commun (10/18/2024)
#
# Title: The developing hippocampus: Microstructural evolution through childhood and adolescence (bioRxiv)
# Authors: ['Karat BG', 'Genc S', 'Raven EP', 'Palombo M', 'Khan AR', 'Jones DK']
# Journal (Date): bioRxiv (8/19/2024)
#
# Title: Cortical Network Disruption Is Minimal in Early Stages of Psychosis (Schizophr Bull Open)
# Authors: ['Van Dyken PC', 'MacKinley M', 'Khan AR', 'Palaniyappan L']
# Journal (Date): Schizophr Bull Open (1/1/2024)
#
# Title: Increased mean diffusivity of the caudal motor SNc identifies patients with REM sleep behaviour disorder and Parkinson's disease (NPJ Parkinsons Dis)
# Authors: ['Alushaj E', 'Hemachandra D', 'Ganjavi H', 'Seergobin KN', 'Sharma M', 'Kashgari A', 'Barr J', 'Reisman W', 'Khan AR', 'MacDonald PA']
# Journal (Date): NPJ Parkinsons Dis (6/29/2024)
#
# Title: Diffusion MRI of the Hippocampus (J Neurosci)
# Authors: ['Karat BG', 'Kohler S', 'Khan AR']
# Journal (Date): J Neurosci (6/5/2024)
#
# Title: MRI-degad: toward accurate conversion of gadolinium-enhanced T1w MRIs to non-contrast-enhanced scans using CNNs (Int J Comput Assist Radiol Surg)
# Authors: ['Ogunsanya F', 'Taha A', 'Gilmore G', 'Kai J', 'Kuehn T', 'Thurairajah A', 'Tenorio MC', 'Khan AR', 'Lau JC']
# Journal (Date): Int J Comput Assist Radiol Surg (7/1/2024)
#
# Title: Increased iron in the substantia nigra pars compacta identifies patients with early Parkinson'sdisease: A 3T and 7T MRI study (Neuroimage Clin)
# Authors: ['Alushaj E', 'Handfield-Jones N', 'Kuurstra A', 'Morava A', 'Menon RS', 'Owen AM', 'Sharma M', 'Khan AR', 'MacDonald PA']
# Journal (Date): Neuroimage Clin (3/1/2024)
#
# Title: Comparison between a deep-learning and a pixel-based approach for the automated quantification of HIV target cells in foreskin tissue (Sci Rep)
# Authors: ['Shao Z', 'Buchanan LB', 'Zuanazzi D', 'Khan YN', 'Khan AR', 'Prodger JL']
# Journal (Date): Sci Rep (1/23/2024)
#
# Title: Assessing brain integrity in patients with long-term and well-functioning metal-based hip implants (J Orthop Res)
# Authors: ['Taleb S', 'Varela-Mattatall G', 'Allen A', 'Haast R', 'Khan AR', 'Kalia V', 'Howard JL', 'MacDonald SJ', 'Menon RS', 'Lanting BA', 'Teeter MG']
# Journal (Date): J Orthop Res (6/1/2024)
#
# Title: Evaluation of surface-based hippocampal registration using ground-truth subfield definitions (Elife)
# Authors: ['DeKraker J', 'Palomero-Gallagher N', 'Kedo O', 'Ladbon-Bernasconi N', 'Muenzing SEA', 'Axer M', 'Amunts K', 'Khan AR', 'Bernhardt BC', 'Evans AC']
# Journal (Date): Elife (11/13/2023)
#
# Title: Focal acetylcholinergic modulation of the human midcingulo-insular network during attention: Meta-analytic neuroimaging and behavioral evidence (J Neurochem)
# Authors: ['Chakraborty S', 'Lee SK', 'Arnold SM', 'Haast RAM', 'Khan AR', 'Schmitz TW']
# Journal (Date): J Neurochem (4/1/2024)
#
# Title: Subregional analysis of striatum iron in Parkinson's disease and rapid eye movement sleep behaviour disorder (Neuroimage Clin)
# Authors: ['Alushaj E', 'Hemachandra D', 'Kuurstra A', 'Menon RS', 'Ganjavi H', 'Sharma M', 'Kashgari A', 'Barr J', 'Reisman W', 'Khan AR', 'MacDonald PA']
# Journal (Date): Neuroimage Clin (3/1/2023)
#
# Title: A population-averaged structural connectomic brain atlas dataset from 422 HCP-aging subjects (Data Brief)
# Authors: ['Xiao Y', 'Gilmore G', 'Kai J', 'Lau JC', 'Peters T', 'Khan AR']
# Journal (Date): Data Brief (10/1/2023)
#
# Title: Mapping the macrostructure and microstructure of the in vivo human hippocampus using diffusion MRI (Hum Brain Mapp)
# Authors: ['Karat BG', 'DeKraker J', 'Hussain U', 'Kohler S', 'Khan AR']
# Journal (Date): Hum Brain Mapp (11/1/2023)
#
# Title: Novel insights into hippocampal perfusion using high-resolution, multi-modal 7T MRI (bioRxiv)
# Authors: ['Haast RAM', 'Kashyap S', 'Ivanov D', 'Yousif MD', 'DeKraker J', 'Poser BA', 'Khan AR']
# Journal (Date): bioRxiv (7/21/2023)
#
# Title: Magnetic resonance imaging datasets with anatomical fiducials for quality control and registration (Sci Data)
# Authors: ['Taha A', 'Gilmore G', 'Abbass M', 'Kai J', 'Kuehn T', 'Demarco J', 'Gupta G', 'Zajner C', 'Cao D', 'Chevalier R', 'Ahmed A', 'Hadi A', 'Karat BG', 'Stanley OW', 'Park PJ', 'Ferko KM', 'Hemachandra D', 'Vassallo R', 'Jach M', 'Thurairajah A', 'Wong S', 'Tenorio MC', 'Ogunsanya F', 'Khan AR', 'Lau JC']
# Journal (Date): Sci Data (7/12/2023)
#
# Title: Data and Tools Integration in the Canadian Open Neuroscience Platform (Sci Data)
# Authors: ['Poline JB', 'Das S', 'Glatard T', 'Madjar C', 'Dickie EW', 'Lecours X', 'Beaudry T', 'Beck N', 'Behan B', 'Brown ST', 'Bujold D', 'Beauvais M', 'Caron B', 'Czech C', 'Dharsee M', 'Dugre M', 'Evans K', 'Gee T', 'Ippoliti G', 'Kiar G', 'Knoppers BM', 'Kuehn T', 'Le D', 'Lo D', 'Mazaheri M', 'MacFarlane D', 'Muja N', "O'Brien EA", "O'Callaghan L", 'Paiva S', 'Park P', 'Quesnel D', 'Rabelais H', 'Rioux P', 'Legault M', 'Tremblay-Mercier J', 'Rotenberg D', 'Stone J', 'Strauss T', 'Zaytseva K', 'Zhou J', 'Duchesne S', 'Khan AR', 'Hill S', 'Evans AC']
# Journal (Date): Sci Data (4/6/2023)
#
# Title: Funcmasker-flex: An Automated BIDS-App for Brain Segmentation of Human Fetal Functional MRI data (Neuroinformatics)
# Authors: ['Nichols ES', 'Correa S', 'Van Dyken P', 'Kai J', 'Kuehn T', 'de Ribaupierre S', 'Duerden EG', 'Khan AR']
# Journal (Date): Neuroinformatics (7/1/2023)
#
# Title: Aberrant frontal lobe "U"-shaped association fibers in first-episode schizophrenia: A 7-Tesla Diffusion Imaging Study (Neuroimage Clin)
# Authors: ['Kai J', 'Mackinley M', 'Khan AR', 'Palaniyappan L']
# Journal (Date): Neuroimage Clin (3/1/2023)
#
# Title: Automated hippocampal unfolding for morphometry and subfield segmentation with HippUnfold (Elife)
# Authors: ['DeKraker J', 'Haast RAM', 'Yousif MD', 'Karat B', 'Lau JC', 'Kohler S', 'Khan AR']
# Journal (Date): Elife (12/15/2022)
#
# Title: The role of the temporal pole in temporal lobe epilepsy: A diffusion kurtosis imaging study (Neuroimage Clin)
# Authors: ['Kasa LW', 'Peters T', 'Mirsattari SM', 'Jurkiewicz MT', 'Khan AR', 'A M Haast R']
# Journal (Date): Neuroimage Clin (3/1/2022)
#
# Title: Microstructural imaging and transcriptomics of the basal forebrain in first-episode psychosis (Transl Psychiatry)
# Authors: ['Park MTM', 'Jeon P', 'French L', 'Dempster K', 'Chakravarty MM', 'MacKinley M', 'Richard J', 'Khan AR', 'Theberge J', 'Palaniyappan L']
# Journal (Date): Transl Psychiatry (9/1/2022)
#
# Title: qMRI-BIDS: An extension to the brain imaging data structure for quantitative magnetic resonance imaging data (Sci Data)
# Authors: ['Karakuzu A', 'Appelhoff S', 'Auer T', 'Boudreau M', 'Feingold F', 'Khan AR', 'Lazari A', 'Markiewicz C', 'Mulder M', 'Phillips C', 'Salo T', 'Stikov N', 'Whitaker K', 'de Hollander G']
# Journal (Date): Sci Data (8/24/2022)
#
# Title: Mapping the subcortical connectome using in vivo diffusion MRI: Feasibility and reliability (Neuroimage)
# Authors: ['Kai J', 'Khan AR', 'Haast RA', 'Lau JC']
# Journal (Date): Neuroimage (11/15/2022)
#
# Title: Three-Dimensional Atlas of the Human Amygdala Subnuclei Constructed Using Immunohistochemical and Ultrahigh-Field Magnetic Resonance Imaging Data (Methods Mol Biol)
# Authors: ['Seguin D', 'Khan AR', 'Duerden EG']
# Journal (Date): Methods Mol Biol (3/1/2022)
#
# Title: Waveform detection by deep learning reveals multi-area spindles that are selectively modulated by memory load (Elife)
# Authors: ['Mofrad MH', 'Gilmore G', 'Koller D', 'Mirsattari SM', 'Burneo JG', 'Steven DA', 'Khan AR', 'Suller Marti A', 'Muller L']
# Journal (Date): Elife (6/29/2022)
#
# Title: Microscopy-BIDS: An Extension to the Brain Imaging Data Structure for Microscopy Data (Front Neurosci)
# Authors: ['Bourget MH', 'Kamentsky L', 'Ghosh SS', 'Mazzamuto G', 'Lazari A', 'Markiewicz CJ', 'Oostenveld R', 'Niso G', 'Halchenko YO', 'Lipp I', 'Takerkart S', 'Toussaint PJ', 'Khan AR', 'Nilsonne G', 'Castelli FM', 'Cohen-Adad J']
# Journal (Date): Front Neurosci (3/1/2022)
#
# Title: Enabling Complex Fibre Geometries Using 3D Printed Axon-Mimetic Phantoms (Front Neurosci)
# Authors: ['Kuehn TK', 'Mushtaha FN', 'Khan AR', 'Baron CA']
# Journal (Date): Front Neurosci (3/1/2022)
#
# Title: Activity in perirhinal and entorhinal cortex predicts perceived visual similarities among category exemplars with highest precision (Elife)
# Authors: ['Ferko KM', 'Blumenthal A', 'Martin CB', 'Proklova D', 'Minos AN', 'Saksida LM', 'Bussey TJ', 'Khan AR', 'Kohler S']
# Journal (Date): Elife (3/21/2022)
#
# Title: Assessing the Reliability of Template-Based Clustering for Tractography in Healthy Human Adults (Front Neuroinform)
# Authors: ['Kai J', 'Khan AR']
# Journal (Date): Front Neuroinform (3/1/2022)
#
# Title: Neurodegenerative and functional signatures of the cerebellar cortex in m.3243A > G patients (Brain Commun)
# Authors: ['Haast RAM', 'De Coo IFM', 'Ivanov D', 'Khan AR', 'Jansen JFA', 'Smeets HJM', 'Uludag K']
# Journal (Date): Brain Commun (3/1/2022)
#
# Title: Application of the anatomical fiducials framework to a clinical dataset of patients with Parkinson's disease (Brain Struct Funct)
# Authors: ['Abbass M', 'Gilmore G', 'Taha A', 'Chevalier R', 'Jach M', 'Peters TM', 'Khan AR', 'Lau JC']
# Journal (Date): Brain Struct Funct (1/1/2022)
#
# Title: Microvessel stenosis, enlarged perivascular spaces, and fibrinogen deposition are associated with ischemic periventricular white matter hyperintensities (Brain Pathol)
# Authors: ['Roseborough AD', 'Rasheed B', 'Jung Y', 'Nishimura K', 'Pinsky W', 'Langdon KD', 'Hammond R', 'Pasternak SH', 'Khan AR', 'Whitehead SN']
# Journal (Date): Brain Pathol (1/1/2022)
#
# Title: Tractography in Curvilinear Coordinates (Front Neurosci)
# Authors: ['Hussain U', 'Baron CA', 'Khan AR']
# Journal (Date): Front Neurosci (3/1/2021)
#
# Title: The BigBrainWarp toolbox for integration of BigBrain 3D histology with multimodal neuroimaging (Elife)
# Authors: ['Paquola C', 'Royer J', 'Lewis LB', 'Lepage C', 'Glatard T', 'Wagstyl K', 'DeKraker J', 'Toussaint PJ', 'Valk SL', 'Collins L', 'Khan AR', 'Amunts K', 'Evans AC', 'Dickscheid T', 'Bernhardt B']
# Journal (Date): Elife (8/25/2021)
#
# Title: Towards a comprehensive 3D mapping of tau progression in early Alzheimer's disease (Brain)
# Authors: ['Khan AR', 'Ottoy J', 'Goubran M']
# Journal (Date): Brain (10/22/2021)
#
# Title: Ultra-High Field 7-Tesla Magnetic Resonance Imaging and Electroencephalography Findings in Epilepsy (Can Assoc Radiol J)
# Authors: ['Salehi F', 'Nadeem IM', 'Kwan BYM', 'Mirsattari SM', 'Lee DH', 'Burneo JG', 'Steven D', 'Hammond R', 'Peters TM', 'Khan AR']
# Journal (Date): Can Assoc Radiol J (5/1/2022)
#
# Title: Surface-based hippocampal subfield segmentation (Trends Neurosci)
# Authors: ['DeKraker J', 'Kohler S', 'Khan AR']
# Journal (Date): Trends Neurosci (11/1/2021)
#
# Title: Design and characterization of a 3D-printed axon-mimetic phantom for diffusion MRI (Magn Reson Med)
# Authors: ['Mushtaha FN', 'Kuehn TK', 'El-Deeb O', 'Rohani SA', 'Helpard LW', 'Moore J', 'Ladak H', 'Moehring A', 'Baron CA', 'Khan AR']
# Journal (Date): Magn Reson Med (11/1/2021)
#
# Title: (18)F-FDG PET-guided diffusion tractography reveals white matter abnormalities around the epileptic focus in medically refractory epilepsy: implications for epilepsy surgical evaluation (Eur J Hybrid Imaging)
# Authors: ['Poirier SE', 'Kwan BYM', 'Jurkiewicz MT', 'Samargandy L', 'Steven DA', 'Suller-Marti A', 'Lam Shin Cheung V', 'Khan AR', 'Romsa J', 'Prato FS', 'Burneo JG', 'Thiessen JD', 'Anazodo UC']
# Journal (Date): Eur J Hybrid Imaging (6/25/2020)
#
# Title: Characterizing white matter alterations subject to clinical laterality in drug-naive de novo Parkinson's disease (Hum Brain Mapp)
# Authors: ['Xiao Y', 'Peters TM', 'Khan AR']
# Journal (Date): Hum Brain Mapp (10/1/2021)
#
# Title: Acute conceptual disorganization in untreated first-episode psychosis: a combined magnetic resonance spectroscopy and diffusion imaging study of the cingulum (J Psychiatry Neurosci)
# Authors: ['Pan Y', 'Dempster K', 'Jeon P', 'Theberge J', 'Khan AR', 'Palaniyappan L']
# Journal (Date): J Psychiatry Neurosci (4/27/2021)
#
# Title: Hippocampal neuroanatomy in first episode psychosis: A putative role for glutamate and serotonin receptors (Prog Neuropsychopharmacol Biol Psychiatry)
# Authors: ['Park MTM', 'Jeon P', 'Khan AR', 'Dempster K', 'Chakravarty MM', 'Lerch JP', 'MacKinley M', 'Theberge J', 'Palaniyappan L']
# Journal (Date): Prog Neuropsychopharmacol Biol Psychiatry (8/30/2021)
#
# Title: Regional Lipid Expression Abnormalities Identified Using MALDI IMS Correspond to MRI-Defined White Matter Hyperintensities within Post-mortem Human Brain Tissues (Anal Chem)
# Authors: ['Pinsky W', 'Harris A', 'Roseborough AD', 'Wang W', 'Khan AR', 'Jurcic K', 'Yeung KK', 'Pasternak SH', 'Whitehead SN']
# Journal (Date): Anal Chem (2/2/2021)
#
# Title: 7T Epilepsy Task Force Consensus Recommendations on the Use of 7T MRI in Clinical Practice (Neurology)
# Authors: ['Opheim G', 'van der Kolk A', 'Markenroth Bloch K', 'Colon AJ', 'Davis KA', 'Henry TR', 'Jansen JFA', 'Jones SE', 'Pan JW', 'Rossler K', 'Stein JM', 'Strandberg MC', 'Trattnig S', 'Van de Moortele PF', 'Vargas MI', 'Wang I', 'Bartolomei F', 'Bernasconi N', 'Bernasconi A', 'Bernhardt B', 'Bjorkman-Burtscher I', 'Cosottini M', 'Das SR', 'Hertz-Pannier L', 'Inati S', 'Jurkiewicz MT', 'Khan AR', 'Liang S', 'Ma RE', 'Mukundan S', 'Pardoe H', 'Pinborg LH', 'Polimeni JR', 'Ranjeva JP', 'Steijvers E', 'Stufflebeam S', 'Veersema TJ', 'Vignaud A', 'Voets N', 'Vulliemoz S', 'Wiggins CJ', 'Xue R', 'Guerrini R', 'Guye M']
# Journal (Date): Neurology (2/16/2021)
#
# Title: Evaluating High Spatial Resolution Diffusion Kurtosis Imaging at 3T: Reproducibility and Quality of Fit (J Magn Reson Imaging)
# Authors: ['Kasa LW', 'Haast RAM', 'Kuehn TK', 'Mushtaha FN', 'Baron CA', 'Peters T', 'Khan AR']
# Journal (Date): J Magn Reson Imaging (4/1/2021)
#
# Title: Effects of MP2RAGE B(1)(+) sensitivity on inter-site T(1) reproducibility and hippocampal morphometry at 7T (Neuroimage)
# Authors: ['Haast RAM', 'Lau JC', 'Ivanov D', 'Menon RS', 'Uludag K', 'Khan AR']
# Journal (Date): Neuroimage (1/1/2021)
#
# Title: Frontal-striatal connectivity and positive symptoms of schizophrenia: implications for the mechanistic basis of prefrontal rTMS (Eur Arch Psychiatry Clin Neurosci)
# Authors: ['Limongi R', 'Mackinley M', 'Dempster K', 'Khan AR', 'Gati JS', 'Palaniyappan L']
# Journal (Date): Eur Arch Psychiatry Clin Neurosci (2/1/2021)
#
# Title: Post-mortem 7 Tesla MRI detection of white matter hyperintensities: A multidisciplinary voxel-wise comparison of imaging and histological correlates (Neuroimage Clin)
# Authors: ['Roseborough AD', 'Langdon KD', 'Hammond R', 'Cipriano LE', 'Pasternak SH', 'Whitehead SN', 'Khan AR']
# Journal (Date): Neuroimage Clin (3/1/2020)
#
# Title: Direct visualization and characterization of the human zona incerta and surrounding structures (Hum Brain Mapp)
# Authors: ['Lau JC', 'Xiao Y', 'Haast RAM', 'Gilmore G', 'Uludag K', 'MacDougall KW', 'Menon RS', 'Parrent AG', 'Peters TM', 'Khan AR']
# Journal (Date): Hum Brain Mapp (11/1/2020)
#
# Title: Striatal shape alteration as a staging biomarker for Parkinson's Disease (Neuroimage Clin)
# Authors: ['Peralta M', 'Baxter JSH', 'Khan AR', 'Haegelen C', 'Jannin P']
# Journal (Date): Neuroimage Clin (3/1/2020)
#
# Title: Assessing Time-Resolved fNIRS for Brain-Computer Interface Applications of Mental Communication (Front Neurosci)
# Authors: ['Abdalmalak A', 'Milej D', 'Yip LCM', 'Khan AR', 'Diop M', 'Owen AM', 'St Lawrence K']
# Journal (Date): Front Neurosci (3/1/2020)
#
# Title: Diffusion dispersion imaging: Mapping oscillating gradient spin-echo frequency dependence in the human brain (Magn Reson Med)
# Authors: ['Arbabi A', 'Kai J', 'Khan AR', 'Baron CA']
# Journal (Date): Magn Reson Med (6/1/2020)
#
# Title: Hippocampal subfields revealed through unfolding and unsupervised clustering of laminar and morphological features in 3D BigBrain (Neuroimage)
# Authors: ['DeKraker J', 'Lau JC', 'Ferko KM', 'Khan AR', 'Kohler S']
# Journal (Date): Neuroimage (2/1/2020)
#
# Title: An accurate registration of the BigBrain dataset with the MNI PD25 and ICBM152 atlases (Sci Data)
# Authors: ['Xiao Y', 'Lau JC', 'Anderson T', 'DeKraker J', 'Collins DL', 'Peters T', 'Khan AR']
# Journal (Date): Sci Data (10/17/2019)
#
# Title: A framework for evaluating correspondence between brain images using anatomical fiducials (Hum Brain Mapp)
# Authors: ['Lau JC', 'Parrent AG', 'Demarco J', 'Gupta G', 'Kai J', 'Stanley OW', 'Kuehn T', 'Park PJ', 'Ferko K', 'Khan AR', 'Peters TM']
# Journal (Date): Hum Brain Mapp (10/1/2019)
#
# Title: Reproducibility of Neurite Orientation Dispersion and Density Imaging (NODDI) in rats at 9.4 Tesla (PLoS One)
# Authors: ['McCunn P', 'Gilbert KM', 'Zeman P', 'Li AX', 'Strong MJ', 'Khan AR', 'Bartha R']
# Journal (Date): PLoS One (3/1/2019)
#
# Title: Biomarkers of Parkinson's disease: Striatal sub-regional structural morphometry and diffusion MRI (Neuroimage Clin)
# Authors: ['Khan AR', 'Hiebert NM', 'Vo A', 'Wang BT', 'Owen AM', 'Seergobin KN', 'MacDonald PA']
# Journal (Date): Neuroimage Clin (3/1/2019)
#
# Title: [18F]-Fluorodeoxyglucose PET/CT imaging as a marker of carotid plaque inflammation: Comparison to immunohistology and relationship to acuity of events (Int J Cardiol)
# Authors: ['Cocker MS', 'Spence JD', 'Hammond R', 'deKemp RA', 'Lum C', 'Wells G', 'Bernick J', 'Hill A', 'Nagpal S', 'Stotts G', 'Alturkustani M', 'Adeeko A', 'Yerofeyeva Y', 'Rayner K', 'Peterson J', 'Khan AR', 'Naidas AC', 'Garrard L', 'Yaffe MJ', 'Leung E', 'Prato FS', 'Tardif JC', 'Beanlands RSB']
# Journal (Date): Int J Cardiol (11/15/2018)
#
# Title: Novel connectivity map normalization procedure for improved quantitative investigation of structural thalamic connectivity in temporal lobe epilepsy patients (J Magn Reson Imaging)
# Authors: ['Santyr BG', 'Lau JC', 'Mirsattari SM', 'Burneo JG', 'de Ribaupierre S', 'Steven DA', 'Parrent AG', 'MacDougall K', 'Khan AR']
# Journal (Date): J Magn Reson Imaging (12/1/2018)
#
# Title: White Matter Tracts in Patients with Temporal Lobe Epilepsy: Pre- and Postoperative Assessment (Cureus)
# Authors: ['Salehi F', 'Sharma M', 'Peters TM', 'Khan AR']
# Journal (Date): Cureus (10/1/2017)
#
# Title: Unfolding the hippocampus: An intrinsic coordinate system for subfield segmentations and quantitative mapping (Neuroimage)
# Authors: ['DeKraker J', 'Ferko KM', 'Lau JC', 'Kohler S', 'Khan AR']
# Journal (Date): Neuroimage (2/15/2018)
#
# Title: Pathophysiology and Risk of Atrial Fibrillation Detected after Ischemic Stroke (PARADISE): A Translational, Integrated, and Transdisciplinary Approach (J Stroke Cerebrovasc Dis)
# Authors: ['Paquet M', 'Cerasuolo JO', 'Thorburn V', 'Fridman S', 'Alsubaie R', 'Lopes RD', 'Cipriano LE', 'Salamone P', 'Melling CWJ', 'Khan AR', 'Sedeno L', 'Fang J', 'Drangova M', 'Montero-Odasso M', 'Mandzia J', 'Khaw AV', 'Racosta JM', 'Paturel J', 'Samoilov L', 'Stirling D', 'Balint B', 'Jaremek V', 'Koschinsky ML', 'Boffa MB', 'Summers K', 'Ibanez A', 'Mrkobrada M', 'Saposnik G', 'Kimpinski K', 'Whitehead SN', 'Sposato LA']
# Journal (Date): J Stroke Cerebrovasc Dis (3/1/2018)
#
# Title: The challenge of mapping the human connectome based on diffusion tractography (Nat Commun)
# Authors: ['Maier-Hein KH', 'Neher PF', 'Houde JC', 'Cote MA', 'Garyfallidis E', 'Zhong J', 'Chamberland M', 'Yeh FC', 'Lin YC', 'Ji Q', 'Reddick WE', 'Glass JO', 'Chen DQ', 'Feng Y', 'Gao C', 'Wu Y', 'Ma J', 'He R', 'Li Q', 'Westin CF', 'Deslauriers-Gauthier S', 'Gonzalez JOO', 'Paquette M', 'St-Jean S', 'Girard G', 'Rheault F', 'Sidhu J', 'Tax CMW', 'Guo F', 'Mesri HY', 'David S', 'Froeling M', 'Heemskerk AM', 'Leemans A', 'Bore A', 'Pinsard B', 'Bedetti C', 'Desrosiers M', 'Brambati S', 'Doyon J', 'Sarica A', 'Vasta R', 'Cerasa A', 'Quattrone A', 'Yeatman J', 'Khan AR', 'Hodges W', 'Alexander S', 'Romascano D', 'Barakovic M', 'Auria A', 'Esteban O', 'Lemkaddem A', 'Thiran JP', 'Cetingul HE', 'Odry BL', 'Mailhe B', 'Nadar MS', 'Pizzagalli F', 'Prasad G', 'Villalon-Reina JE', 'Galvis J', 'Thompson PM', 'Requejo FS', 'Laguna PL', 'Lacerda LM', 'Barrett R', "Dell'Acqua F", 'Catani M', 'Petit L', 'Caruyer E', 'Daducci A', 'Dyrby TB', 'Holland-Letz T', 'Hilgetag CC', 'Stieltjes B', 'Descoteaux M']
# Journal (Date): Nat Commun (11/7/2017)
#
# Title: MultiXplore: Visual exploration platform for multimodal neuroimaging data (J Neurosci Methods)
# Authors: ['Bakhshmand SM', 'Khan AR', 'de Ribaupierre S', 'Eagleson R']
# Journal (Date): J Neurosci Methods (10/1/2017)
#
# Title: Evaluation of ex-vivo 9.4T MRI in post-surgical specimens from temporal lobe epilepsy patients (J Neuroradiol)
# Authors: ['Kwan BYM', 'Salehi F', 'Kope R', 'Lee DH', 'Sharma M', 'Hammond R', 'Burneo JG', 'Steven D', 'Peters T', 'Khan AR']
# Journal (Date): J Neuroradiol (10/1/2017)
#
# Title: Ultra-High Field Template-Assisted Target Selection for Deep Brain Stimulation Surgery (World Neurosurg)
# Authors: ['Lau JC', 'MacDougall KW', 'Arango MF', 'Peters TM', 'Parrent AG', 'Khan AR']
# Journal (Date): World Neurosurg (7/1/2017)
#
# Title: Quantification of local geometric distortion in structural magnetic resonance images: Application to ultra-high fields (Neuroimage)
# Authors: ['Lau JC', 'Khan AR', 'Zeng TY', 'MacDougall KW', 'Parrent AG', 'Peters TM']
# Journal (Date): Neuroimage (3/1/2018)
#
# Title: Usage of SWI (susceptibility weighted imaging) acquired at 7T for qualitative evaluation of temporal lobe epilepsy patients with histopathological and clinical correlation: An initial pilot study (J Neurol Sci)
# Authors: ['Kwan BYM', 'Salehi F', 'Ohorodnyk P', 'Lee DH', 'Burneo JG', 'Mirsattari SM', 'Steven D', 'Hammond R', 'Peters TM', 'Khan AR']
# Journal (Date): J Neurol Sci (10/15/2016)
#
# Title: Investigation of hippocampal substructures in focal temporal lobe epilepsy with and without hippocampal sclerosis at 7T (J Magn Reson Imaging)
# Authors: ['Santyr BG', 'Goubran M', 'Lau JC', 'Kwan BYM', 'Salehi F', 'Lee DH', 'Mirsattari SM', 'Burneo JG', 'Steven DA', 'Parrent AG', 'de Ribaupierre S', 'Hammond RR', 'Peters TM', 'Khan AR']
# Journal (Date): J Magn Reson Imaging (5/1/2017)
#
# Title: MRBrainS Challenge: Online Evaluation Framework for Brain Image Segmentation in 3T MRI Scans (Comput Intell Neurosci)
# Authors: ['Mendrik AM', 'Vincken KL', 'Kuijf HJ', 'Breeuwer M', 'Bouvy WH', 'de Bresser J', 'Alansary A', 'de Bruijne M', 'Carass A', 'El-Baz A', 'Jog A', 'Katyal R', 'Khan AR', 'van der Lijn F', 'Mahmood Q', 'Mukherjee R', 'van Opbroek A', 'Paneri S', 'Pereira S', 'Persson M', 'Rajchl M', 'Sarikaya D', 'Smedby O', 'Silva CA', 'Vrooman HA', 'Vyas S', 'Wang C', 'Zhao L', 'Biessels GJ', 'Viergever MA']
# Journal (Date): Comput Intell Neurosci (3/1/2015)
#
# Title: In vivo MRI signatures of hippocampal subfield pathology in intractable epilepsy (Hum Brain Mapp)
# Authors: ['Goubran M', 'Bernhardt BC', 'Cantor-Rivera D', 'Lau JC', 'Blinston C', 'Hammond RR', 'de Ribaupierre S', 'Burneo JG', 'Mirsattari SM', 'Steven DA', 'Parrent AG', 'Bernasconi A', 'Bernasconi N', 'Peters TM', 'Khan AR']
# Journal (Date): Hum Brain Mapp (3/1/2016)
#
# Title: Individual feature maps: a patient-specific analysis tool with applications in temporal lobe epilepsy (Int J Comput Assist Radiol Surg)
# Authors: ['Cantor-Rivera D', 'Baxter JS', 'de Ribaupierrre S', 'Lau JC', 'Mirsattari SM', 'Goubran M', 'Burneo JG', 'Steven DA', 'Peters TM', 'Khan AR']
# Journal (Date): Int J Comput Assist Radiol Surg (1/1/2016)
#
# Title: Hierarchical max-flow segmentation framework for multi-atlas segmentation with Kohonen self-organizing map based Gaussian mixture modeling (Med Image Anal)
# Authors: ['Rajchl M', 'Baxter JS', 'McLeod AJ', 'Yuan J', 'Qiu W', 'Peters TM', 'Khan AR']
# Journal (Date): Med Image Anal (1/1/2016)
#
# Title: Registration of in-vivo to ex-vivo MRI of surgically resected specimens: a pipeline for histology to in-vivo registration (J Neurosci Methods)
# Authors: ['Goubran M', 'de Ribaupierre S', 'Hammond RR', 'Currie C', 'Burneo JG', 'Parrent AG', 'Peters TM', 'Khan AR']
# Journal (Date): J Neurosci Methods (2/15/2015)
#
# Title: Magnetic resonance imaging and histology correlation in the neocortex in temporal lobe epilepsy (Ann Neurol)
# Authors: ['Goubran M', 'Hammond RR', 'de Ribaupierre S', 'Burneo JG', 'Mirsattari S', 'Steven DA', 'Parrent AG', 'Peters TM', 'Khan AR']
# Journal (Date): Ann Neurol (2/1/2015)
#
# Title: Unified voxel- and tensor-based morphometry (UVTBM) using registration confidence (Neurobiol Aging)
# Authors: ['Khan AR', 'Wang L', 'Beg MF']
# Journal (Date): Neurobiol Aging (1/1/2015)
#
# Title: Detection of temporal lobe epilepsy using support vector machines in multi-parametric quantitative MR imaging (Comput Med Imaging Graph)
# Authors: ['Cantor-Rivera D', 'Khan AR', 'Goubran M', 'Mirsattari SM', 'Peters TM']
# Journal (Date): Comput Med Imaging Graph (4/1/2015)

# %%
# Also output the df in case output limit exceeded
new_pubs
# Out:
#         pmid        pmcid                                   doi  \
# 0   41680562                         10.1038/s42003-026-09622-x
# 1   41531669  PMC12794307                   10.1162/IMAG.a.1080
# 2   41280080  PMC12632981             10.1101/2025.10.15.682705
# 3   41034610  PMC12510884            10.1038/s41592-025-02783-3
# 4   40800408  PMC12272272                  10.1162/imag_a_00221
# ..       ...          ...                                   ...
# 89  26072170                        10.1016/j.media.2015.05.005
# 90  25514760                     10.1016/j.jneumeth.2014.12.005
# 91  25424188                                  10.1002/ana.24318
# 92  25264347   PMC8026273  10.1016/j.neurobiolaging.2014.04.036
# 93  25103878                  10.1016/j.compmedimag.2014.07.002
#
#                                                 title  \
# 0   Microstructural variation of hippocampal subst...
# 1   Revisiting the interpretation of axon diameter...
# 2   Hippocampal grey matter changes across scales ...
# 3   HippoMaps: multiscale cartography of human hip...
# 4   Imaging of the superficial white matter in hea...
# ..                                                ...
# 89  Hierarchical max-flow segmentation framework f...
# 90  Registration of in-vivo to ex-vivo MRI of surg...
# 91  Magnetic resonance imaging and histology corre...
# 92  Unified voxel- and tensor-based morphometry (U...
# 93  Detection of temporal lobe epilepsy using supp...
#
#                                               authors  year  month  day  \
# 0   [Karat BG, Genc S, Raven EP, Palombo M, Khan A...  2026      2   12
# 1   [Karat BG, Wren-Jarvis J, Raven EP, Khan AR, J...  2026      3    1
# 2   [Karat BG, Farahani MV, Davidson M, Thurairaja...  2025     10   15
# 3   [DeKraker J, Cabalo DG, Royer J, Ngo A, Khan A...  2025     10    1
# 4             [Van Dyken PC, Khan AR, Palaniyappan L]  2024      3    1
# ..                                                ...   ...    ...  ...
# 89  [Rajchl M, Baxter JS, McLeod AJ, Yuan J, Qiu W...  2016      1    1
# 90  [Goubran M, de Ribaupierre S, Hammond RR, Curr...  2015      2   15
# 91  [Goubran M, Hammond RR, de Ribaupierre S, Burn...  2015      2    1
# 92                          [Khan AR, Wang L, Beg MF]  2015      1    1
# 93  [Cantor-Rivera D, Khan AR, Goubran M, Mirsatta...  2015      4    1
#
#                      journal      volume    issue      pages
# 0                Commun Biol
# 1    Imaging Neurosci (Camb)           4
# 2                    bioRxiv
# 3                Nat Methods          22       10  2211-2222
# 4    Imaging Neurosci (Camb)           2
# ..                       ...         ...      ...        ...
# 89            Med Image Anal          27               45-56
# 90        J Neurosci Methods         241               53-65
# 91                Ann Neurol          77        2     237-50
# 92           Neurobiol Aging  36 Suppl 1  Suppl 1      S60-8
# 93  Comput Med Imaging Graph          41               14-28
#
# [90 rows x 12 columns]
